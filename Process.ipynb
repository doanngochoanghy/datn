# %%
import pandas as pd
import codecs
from nltk.tokenize import RegexpTokenizer

col_Names=["PostID","PostLabel", "SegmentedPostLabel", "SegmentedPost", "Tokenized"]
df = pd.read_csv(codecs.open('data.csv','rU','UTF-8'), sep=',',header=0,names=col_Names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-71a956e29fd2> in <module>()
#       4
#       5 col_Names=["PostID","PostLabel", "SegmentedPostLabel", "SegmentedPost", "Tokenized"]
# ----> 6 df = pd.read_csv(codecs.open('data.csv','rU','UTF-8'), sep=',',header=0,names=col_Names)
#
# /usr/lib/python3.6/codecs.py in open(filename, mode, encoding, errors, buffering)
#     895         # Force opening of the file in binary mode
#     896         mode = mode + 'b'
# --> 897     file = builtins.open(filename, mode, buffering)
#     898     if encoding is None:
#     899         return file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.csv'

# %%
df.shape

# %%
df.head()

# %%
neg=df[df["SegmentedPostLabel"]==-1].shape[0]
neu=df[df["SegmentedPostLabel"]==0].shape[0]
pos=df[df["SegmentedPostLabel"]==1].shape[0]

# %%
print("Neg: ",neg)
print("Neu: ",neu)
print("Pos: ",pos)

# %%
neg+neu+pos

# %%
df[~df["SegmentedPostLabel"].isin([0,1,-1])]
